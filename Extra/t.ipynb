# %%
def a(n):
    for i in range(n):
        print(i)
a(5)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def a(n):
    for i in range(n):
        return i
a(5)
# Out:
# 0

# %%
def a(n):
    for i in range(n):
        yield i
b = a(5)
print(next(b))
# Out:
# 0

# %%
a=[1,2,3,4]
a[1]
# Out:
# 1

# %%
prices = [5,1,4,3,6]

# %%
prices = [7,6,4,3,1]

# %%
prices = [2, 4, 1]

# %%
buy = min(prices)
bIndex = prices.index(buy)
print('prices: ',prices)
print('buy: ', buy)
print('bIndex: ', bIndex)
print('max(prices[bIndex:]): ',max(prices[bIndex:]))

if prices[bIndex + 1:]:
    sell = max(prices[bIndex + 1:])
    profit = sell-buy

    sell = max(prices[bIndex + 1:]) if max(prices[bIndex:]) != buy else 0
    profit = sell-buy if sell else 0 
    
else:
    profit = 0
print(profit)
# Out:
# prices:  [2, 4, 1]
# buy:  1
# bIndex:  2
# max(prices[bIndex:]):  1
# 0

# %%
prices = [2,4,1]

# %%
bIndex = 2

# %%
if prices[bIndex + 1:]:
    print(11)
else:
    print(22)
# Out:
# 22

# %%
maxProfit([5,3,4,1,6])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 maxProfit([5,3,4,1,6])
#
# TypeError: maxProfit() missing 1 required positional argument: 'prices'
