# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from urllib.parse import urljoin

# %%
BASE_URL = "https://www.daiict.ac.in"
FACULTY_URL = "https://www.daiict.ac.in/faculty"

HEADERS = {
    "User-Agent": "AcademicProjectBot/1.0 (For educational use only)"
}

DELAY = 2  # seconds between requests (polite crawling)

def fetch_page(url):
    """Fetch a webpage safely."""
    try:
        response = requests.get(url, headers=HEADERS, timeout=15)
        response.raise_for_status()
        return response.text
    except requests.exceptions.RequestException as e:
        print(f"[ERROR] Failed to fetch {url} -> {e}")
        return None


def parse_faculty_list(html):
    """Extract faculty profile links from the main faculty page."""
    soup = BeautifulSoup(html, "html.parser")

    faculty_links = []

    # Inspect the page structure:
    # Faculty entries are typically in <a> tags linking to individual profiles
    for link in soup.select("a[href]"):
        href = link.get("href")

        # Keep only faculty profile links
        if href and "/faculty/" in href:
            full_url = urljoin(BASE_URL, href)
            if full_url not in faculty_links:
                faculty_links.append(full_url)

    return faculty_links


def parse_faculty_profile(html, profile_url):
    """Extract structured information from an individual faculty profile."""
    soup = BeautifulSoup(html, "html.parser")

    data = {
        "name": None,
        "designation": None,
        "qualification": None,
        "research_interests": None,
        "profile_url": profile_url
    }

    # --- NAME ---
    name_tag = soup.find("h1")
    if name_tag:
        data["name"] = name_tag.get_text(strip=True)

    # --- DESIGNATION / ROLE ---
    designation = soup.find("div", class_="field--name-field-designation")
    if designation:
        data["designation"] = designation.get_text(strip=True)

    # --- QUALIFICATION ---
    qualification = soup.find("div", class_="field--name-field-qualification")
    if qualification:
        data["qualification"] = qualification.get_text(strip=True)

    # --- RESEARCH INTERESTS ---
    research = soup.find("div", class_="field--name-field-research-interests")
    if research:
        data["research_interests"] = research.get_text(" ", strip=True)

    return data


def main():
    print("[INFO] Fetching faculty listing page...")
    main_page = fetch_page(FACULTY_URL)

    if not main_page:
        print("[ERROR] Could not load faculty page.")
        return

    print("[INFO] Parsing faculty links...")
    faculty_links = parse_faculty_list(main_page)
    print(f"[INFO] Found {len(faculty_links)} faculty profile links")

    faculty_data = []

    for idx, profile_url in enumerate(faculty_links, start=1):
        print(f"[INFO] ({idx}/{len(faculty_links)}) Fetching: {profile_url}")
        html = fetch_page(profile_url)

        if html:
            data = parse_faculty_profile(html, profile_url)
            faculty_data.append(data)

        time.sleep(DELAY)  # Polite crawling

    # Save to CSV
    df = pd.DataFrame(faculty_data)
    df.to_csv("daiict_faculty_data.csv", index=False)

    print("[SUCCESS] Data saved to daiict_faculty_data.csv")
    print(df.head())
    return df


if __name__ == "__main__":
    df = main()
# Out:
# [INFO] Fetching faculty listing page...
# [INFO] Parsing faculty links...
# [INFO] Found 66 faculty profile links
# [INFO] (1/66) Fetching: https://www.daiict.ac.in/faculty/abhishek-gupta
# [INFO] (2/66) Fetching: https://www.daiict.ac.in/faculty/abhishek-jindal
# [INFO] (3/66) Fetching: https://www.daiict.ac.in/faculty/abhishek-tilva
# [INFO] (4/66) Fetching: https://www.daiict.ac.in/faculty/aditya-tatu
# [INFO] (5/66) Fetching: https://www.daiict.ac.in/faculty/ajay-beniwal
# [INFO] (6/66) Fetching: https://www.daiict.ac.in/faculty/amit-mankodi
# [INFO] (7/66) Fetching: https://www.daiict.ac.in/faculty/anil-roy
# [INFO] (8/66) Fetching: https://www.daiict.ac.in/faculty/anish-mathuria
# [INFO] (9/66) Fetching: https://www.daiict.ac.in/faculty/ankit-vijayvargiya
# [INFO] (10/66) Fetching: https://www.daiict.ac.in/faculty/anupam-rana
# [INFO] (11/66) Fetching: https://www.daiict.ac.in/faculty/arnab-kumar-ray
# [INFO] (12/66) Fetching: https://www.daiict.ac.in/faculty/arpit-rana
# [INFO] (13/66) Fetching: https://www.daiict.ac.in/faculty/arpita-mal
# [INFO] (14/66) Fetching: https://www.daiict.ac.in/faculty/bharani-kollipara
# [INFO] (15/66) Fetching: https://www.daiict.ac.in/faculty/bhaskar-chaudhury
# [INFO] (16/66) Fetching: https://www.daiict.ac.in/faculty/biswajit-mishra
# [INFO] (17/66) Fetching: https://www.daiict.ac.in/faculty/gautam-dutta
# [INFO] (18/66) Fetching: https://www.daiict.ac.in/faculty/gopinath-panda
# [INFO] (19/66) Fetching: https://www.daiict.ac.in/faculty/hemant-patil
# [INFO] (20/66) Fetching: https://www.daiict.ac.in/faculty/jenson-joseph
# [INFO] (21/66) Fetching: https://www.daiict.ac.in/faculty/madhu-kant-sharma
# [INFO] (22/66) Fetching: https://www.daiict.ac.in/faculty/madhumita-mazumdar
# [INFO] (23/66) Fetching: https://www.daiict.ac.in/faculty/maniklal-das
# [INFO] (24/66) Fetching: https://www.daiict.ac.in/faculty/manish-chaturvedi
# [INFO] (25/66) Fetching: https://www.daiict.ac.in/faculty/manish-kumar
# [INFO] (26/66) Fetching: https://www.daiict.ac.in/faculty/manjunath-v-joshi
# [INFO] (27/66) Fetching: https://www.daiict.ac.in/faculty/manoj-raut
# [INFO] (28/66) Fetching: https://www.daiict.ac.in/faculty/minal-bhise
# [INFO] (29/66) Fetching: https://www.daiict.ac.in/faculty/mukesh-tiwari
# [INFO] (30/66) Fetching: https://www.daiict.ac.in/faculty/nabin-kumar-sahu
# [INFO] (31/66) Fetching: https://www.daiict.ac.in/faculty/p-m-jat
# [INFO] (32/66) Fetching: https://www.daiict.ac.in/faculty/p-s-kalyan-sasidhar
# [INFO] (33/66) Fetching: https://www.daiict.ac.in/faculty/pankaj-kumar
# [INFO] (34/66) Fetching: https://www.daiict.ac.in/faculty/parul-gupta
# [INFO] (35/66) Fetching: https://www.daiict.ac.in/faculty/prasenjit-majumder
# [INFO] (36/66) Fetching: https://www.daiict.ac.in/faculty/pratim-roy
# [INFO] (37/66) Fetching: https://www.daiict.ac.in/faculty/pritam-anand
# [INFO] (38/66) Fetching: https://www.daiict.ac.in/faculty/prosenjit-kundu
# [INFO] (39/66) Fetching: https://www.daiict.ac.in/faculty/puneet-bhateja
# [INFO] (40/66) Fetching: https://www.daiict.ac.in/faculty/purbasha-das
# [INFO] (41/66) Fetching: https://www.daiict.ac.in/faculty/pushpendra-kumar
# [INFO] (42/66) Fetching: https://www.daiict.ac.in/faculty/rachit-chhaya
# [INFO] (43/66) Fetching: https://www.daiict.ac.in/faculty/rahul-muthu
# [INFO] (44/66) Fetching: https://www.daiict.ac.in/faculty/rajib-lochan-das
# [INFO] (45/66) Fetching: https://www.daiict.ac.in/faculty/ratna-bharati-bhamidipati
# [INFO] (46/66) Fetching: https://www.daiict.ac.in/faculty/rutu-parekh
# [INFO] (47/66) Fetching: https://www.daiict.ac.in/faculty/sandip-modha
# [INFO] (48/66) Fetching: https://www.daiict.ac.in/faculty/sanjay-srivastava
# [INFO] (49/66) Fetching: https://www.daiict.ac.in/faculty/satvik-gupta
# [INFO] (50/66) Fetching: https://www.daiict.ac.in/faculty/saurabh-tiwari
# [INFO] (51/66) Fetching: https://www.daiict.ac.in/faculty/sayantan-paul
# [INFO] (52/66) Fetching: https://www.daiict.ac.in/faculty/shefali-jha
# [INFO] (53/66) Fetching: https://www.daiict.ac.in/faculty/shruti-bhilare
# [INFO] (54/66) Fetching: https://www.daiict.ac.in/faculty/sourish-dasgupta
# [INFO] (55/66) Fetching: https://www.daiict.ac.in/faculty/sreeja-rajendran
# [INFO] (56/66) Fetching: https://www.daiict.ac.in/faculty/srimanta-mandal
# [INFO] (57/66) Fetching: https://www.daiict.ac.in/faculty/subhasish-basak
# [INFO] (58/66) Fetching: https://www.daiict.ac.in/faculty/sudip-bera
# [INFO] (59/66) Fetching: https://www.daiict.ac.in/faculty/sujay-kadam
# [INFO] (60/66) Fetching: https://www.daiict.ac.in/faculty/sunitha-v
# [INFO] (61/66) Fetching: https://www.daiict.ac.in/faculty/supantha-pandit
# [INFO] (62/66) Fetching: https://www.daiict.ac.in/faculty/tapas-kumar-maiti
# [INFO] (63/66) Fetching: https://www.daiict.ac.in/faculty/tathagata-bandyopadhyay
# [INFO] (64/66) Fetching: https://www.daiict.ac.in/faculty/vinay-palaparthy
# [INFO] (65/66) Fetching: https://www.daiict.ac.in/faculty/yash-agrawal
# [INFO] (66/66) Fetching: https://www.daiict.ac.in/faculty/yash-vasavada
# [SUCCESS] Data saved to daiict_faculty_data.csv
#    name designation qualification research_interests  \
# 0  logo        None          None               None
# 1  logo        None          None               None
# 2  logo        None          None               None
# 3  logo        None          None               None
# 4  logo        None          None               None
#
#                                         profile_url
# 0   https://www.daiict.ac.in/faculty/abhishek-gupta
# 1  https://www.daiict.ac.in/faculty/abhishek-jindal
# 2   https://www.daiict.ac.in/faculty/abhishek-tilva
# 3      https://www.daiict.ac.in/faculty/aditya-tatu
# 4     https://www.daiict.ac.in/faculty/ajay-beniwal

# %%
df
# Out:
#     name designation qualification research_interests  \
# 0   logo        None          None               None
# 1   logo        None          None               None
# 2   logo        None          None               None
# 3   logo        None          None               None
# 4   logo        None          None               None
# ..   ...         ...           ...                ...
# 61  logo        None          None               None
# 62  logo        None          None               None
# 63  logo        None          None               None
# 64  logo        None          None               None
# 65  logo        None          None               None
#
#                                           profile_url
# 0     https://www.daiict.ac.in/faculty/abhishek-gupta
# 1    https://www.daiict.ac.in/faculty/abhishek-jindal
# 2     https://www.daiict.ac.in/faculty/abhishek-tilva
# 3        https://www.daiict.ac.in/faculty/aditya-tatu
# 4       https://www.daiict.ac.in/faculty/ajay-beniwal
# ..                                                ...
# 61  https://www.daiict.ac.in/faculty/tapas-kumar-m...
# 62  https://www.daiict.ac.in/faculty/tathagata-ban...
# 63  https://www.daiict.ac.in/faculty/vinay-palaparthy
# 64      https://www.daiict.ac.in/faculty/yash-agrawal
# 65     https://www.daiict.ac.in/faculty/yash-vasavada
#
# [66 rows x 5 columns]

# %%
df.fillna("Not Available", inplace=True)

# %%
item = {1:11,3:None,4:"", 5:[], 6:[1,2]}
item.get(1)
# Out:
# 11

# %%
item.get(2)

# %%
cleaned_data = {key: (item.get(key) if item.get(key) else None) for key in item.keys()}

# %% [markdown]
# re.sub(r'\D', '', '  34')

# %%
import re
re.sub(r'\D', '', '  a1 34')
# Out:
# '134'

# %%
{key: (item.get(key) if item.get(key) else None) for key in item.keys()}
# Out:
# {1: 11, 3: None, 4: None}

# %%
{key: item.get(key) for key in item.keys()}
# Out:
# {1: 11, 3: None, 4: ''}
